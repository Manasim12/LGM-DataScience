# %% [markdown]
# <h1>Lets Grow More</h1>
# <h3>Name:</h3>Manasi More.
#
# <h6>Task 3:</h6> Image to Pencil Sketch with Python

# %% [markdown]
# <h2>Importing Libraries</h2>

# %%
# !pip install opencv-python

# %%
import cv2
from PIL import Image
from IPython.display import display
import matplotlib.pyplot as plt

# %% [markdown]
# <h2>Loading and Plotting the Original image</h2>

# %%
image = cv2.imread('C:\\Users\\Manasi more\\Downloads\\theme.jpg')
plt.figure(figsize=(9,15))
image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.axis("off")
plt.title("REAL IMAGE")
plt.show()

# %% [markdown]
# <h2>Converting Original image to Grayscale</h2>

# %%
image_gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(9,15))
plt.imshow(image_gray,cmap="gray")
plt.axis("off")
plt.title("GRAYSCALE IMAGE")
plt.show()

# %% [markdown]
# <h2>Inverting the Image</h2>

# %%
image_invert=cv2.bitwise_not(image_gray)
plt.figure(figsize=(9,15))
plt.imshow(image_gray,cmap="gray")
plt.axis("off")
plt.title("INVERTED IMAGE")
plt.show()

# %% [markdown]
# <h2>Smoothing the Image</h2>

# %%
blurred=cv2.GaussianBlur(image_invert,(21,21),0)
plt.figure(figsize=(9,15))
plt.imshow(blurred,cmap="gray")
plt.axis("off")
plt.title("BLURRED IMAGE")
plt.show()

# %% [markdown]
# <h2>Converting the image into pencil sketch</h2>

# %%
pencil_sketch=cv2.divide(image_gray,255-blurred,scale=255)
plt.figure(figsize=(9,15))
plt.imshow(pencil_sketch,cmap="gray")
plt.title("FINAL IMAGE")
plt.axis("off")
# Out:
# (-0.5, 473.5, 295.5, -0.5)
